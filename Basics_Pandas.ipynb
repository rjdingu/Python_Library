# %%
import pandas as pd

# %% [markdown]
# Series()

# %%
s = pd.Series([6,34,23,56,43])
s
# Out:
# 0     6
# 1    34
# 2    23
# 3    56
# 4    43
# dtype: int64

# %%
s.dtype
# Out:
# dtype('int64')

# %%
s.values
# Out:
# array([ 6, 34, 23, 56, 43])

# %%
s.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
print(s.name)
# Out:
# None

# %%
s.name = 'Sample Series'
s
# Out:
# 0     6
# 1    34
# 2    23
# 3    56
# 4    43
# Name: Sample Series, dtype: int64

# %%
s[0:3]
# Out:
# 0     6
# 1    34
# 2    23
# Name: Sample Series, dtype: int64

# %% [markdown]
# # iloc[ ]   -> Location Based Indexing

# %%
s.iloc[0:3]
# Out:
# 0     6
# 1    34
# 2    23
# Name: Sample Series, dtype: int64

# %%
s.name = 'calories table'
s
# Out:
# 0     6
# 1    34
# 2    23
# 3    56
# 4    43
# Name: calories table, dtype: int64

# %%
i = ['Apple','Banana','Mango','Guava',"Watermelon"]
s.index = i
s
# Out:
# Apple          6
# Banana        34
# Mango         23
# Guava         56
# Watermelon    43
# Name: calories table, dtype: int64

# %%
s.iloc[0:3]
# Out:
# Apple      6
# Banana    34
# Mango     23
# Name: calories table, dtype: int64

# %%
s
# Out:
# Apple          6
# Banana        34
# Mango         23
# Guava         56
# Watermelon    43
# Name: calories table, dtype: int64

# %% [markdown]
# # loc [ ] -> Label Based Location

# %%
s.loc['Banana':'Watermelon']
# Out:
# Banana        34
# Mango         23
# Guava         56
# Watermelon    43
# Name: calories table, dtype: int64

# %% [markdown]
# # **Series By Dictionary**

# %%
s1 = pd.Series({'LED TV': 12000,'AC': 25000,'Washing Machine': 14000,'Refrigerator': 19000,'Fan': 2500,'LED Light': 800,'Sofa': 28000 },name = 'Price')
s1
# Out:
# LED TV             12000
# AC                 25000
# Washing Machine    14000
# Refrigerator       19000
# Fan                 2500
# LED Light            800
# Sofa               28000
# Name: Price, dtype: int64

# %%
s1.name
# Out:
# 'Price'

# %% [markdown]
# # Conditional Statement

# %%
s1[(s1<15000) & (s1>10000)]
# Out:
# LED TV             12000
# Washing Machine    14000
# Name: Price, dtype: int64

# %%
s1["Sofa"] = 35000
s1
# Out:
# LED TV             12000
# AC                 25000
# Washing Machine    14000
# Refrigerator       19000
# Fan                 2500
# LED Light            800
# Sofa               35000
# Name: Price, dtype: int64

# %%
print(s1.is_unique)
# Out:
# True

# %%
import numpy as np

# %% [markdown]
# # **Dataframe**

# %%
data ={
    'Name': ['Raj','Alone','Bob','Kamal','Geetha','Steve','Lalith'],
    'Experiance': [10,5,np.nan,1,2,7,5],
    'Salary' : [120000,45000,55000,25000,np.nan,60000,20000],
    'Role': ['ML Engineer','Software Engineer','Software Engineer','ML Engineer','HR','HR','Data Scientist']
    }


print(data)
# Out:
# {'Name': ['Raj', 'Alone', 'Bob', 'Kamal', 'Geetha', 'Steve', 'Lalith'], 'Experiance': [10, 5, nan, 1, 2, 7, 5], 'Salary': [120000, 45000, 55000, 25000, nan, 60000, 20000], 'Role': ['ML Engineer', 'Software Engineer', 'Software Engineer', 'ML Engineer', 'HR', 'HR', 'Data Scientist']}

# %%
df = pd.DataFrame(data)
df
# Out:
#      Name  Experiance    Salary               Role
# 0     Raj        10.0  120000.0        ML Engineer
# 1   Alone         5.0   45000.0  Software Engineer
# 2     Bob         NaN   55000.0  Software Engineer
# 3   Kamal         1.0   25000.0        ML Engineer
# 4  Geetha         2.0       NaN                 HR
# 5   Steve         7.0   60000.0                 HR
# 6  Lalith         5.0   20000.0     Data Scientist

# %%
df.head(2)
# Out:
#     Name  Experiance    Salary               Role
# 0    Raj        10.0  120000.0        ML Engineer
# 1  Alone         5.0   45000.0  Software Engineer

# %%
df.tail(2)
# Out:
#      Name  Experiance   Salary            Role
# 5   Steve         7.0  60000.0              HR
# 6  Lalith         5.0  20000.0  Data Scientist

# %%
df.loc[0:2,'Name':'Salary']
# Out:
#     Name  Experiance    Salary
# 0    Raj        10.0  120000.0
# 1  Alone         5.0   45000.0
# 2    Bob         NaN   55000.0

# %%
df.iloc[0:3,1:3]
# Out:
#    Experiance    Salary
# 0        10.0  120000.0
# 1         5.0   45000.0
# 2         NaN   55000.0

# %%
df[['Name','Salary']]
# Out:
#      Name    Salary
# 0     Raj  120000.0
# 1   Alone   45000.0
# 2     Bob   55000.0
# 3   Kamal   25000.0
# 4  Geetha       NaN
# 5   Steve   60000.0
# 6  Lalith   20000.0

# %%
df.drop('Experiance',axis = 1)
# Out:
#      Name    Salary               Role
# 0     Raj  120000.0        ML Engineer
# 1   Alone   45000.0  Software Engineer
# 2     Bob   55000.0  Software Engineer
# 3   Kamal   25000.0        ML Engineer
# 4  Geetha       NaN                 HR
# 5   Steve   60000.0                 HR
# 6  Lalith   20000.0     Data Scientist

# %%
df
# Out:
#      Name  Experiance    Salary               Role
# 0     Raj        10.0  120000.0        ML Engineer
# 1   Alone         5.0   45000.0  Software Engineer
# 2     Bob         NaN   55000.0  Software Engineer
# 3   Kamal         1.0   25000.0        ML Engineer
# 4  Geetha         2.0       NaN                 HR
# 5   Steve         7.0   60000.0                 HR
# 6  Lalith         5.0   20000.0     Data Scientist

# %%
df.shape
# Out:
# (7, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        7 non-null      object
#  1   Experiance  6 non-null      float64
#  2   Salary      6 non-null      float64
#  3   Role        7 non-null      object
# dtypes: float64(2), object(2)
# memory usage: 356.0+ bytes

# %%
df.describe()
# Out:
#        Experiance         Salary
# count    6.000000       6.000000
# mean     5.000000   54166.666667
# std      3.286335   35974.528026
# min      1.000000   20000.000000
# 25%      2.750000   30000.000000
# 50%      5.000000   50000.000000
# 75%      6.500000   58750.000000
# max     10.000000  120000.000000

# %%
df['Salary'] = df['Salary'] + 5500
df
# Out:
#      Name  Experiance    Salary               Role
# 0     Raj        10.0  125500.0        ML Engineer
# 1   Alone         5.0   50500.0  Software Engineer
# 2     Bob         NaN   60500.0  Software Engineer
# 3   Kamal         1.0   30500.0        ML Engineer
# 4  Geetha         2.0       NaN                 HR
# 5   Steve         7.0   65500.0                 HR
# 6  Lalith         5.0   25500.0     Data Scientist

# %%
df.rename(columns = {'Name':'Employee'},inplace = True)

# %%
df
# Out:
#   Employee  Experiance    Salary               Role
# 0      Raj        10.0  125500.0        ML Engineer
# 1    Alone         5.0   50500.0  Software Engineer
# 2      Bob         NaN   60500.0  Software Engineer
# 3    Kamal         1.0   30500.0        ML Engineer
# 4   Geetha         2.0       NaN                 HR
# 5    Steve         7.0   65500.0                 HR
# 6   Lalith         5.0   25500.0     Data Scientist

# %%
df['Role'].value_counts()
# Out:
# Role
# ML Engineer          2
# Software Engineer    2
# HR                   2
# Data Scientist       1
# Name: count, dtype: int64

# %%
df['Promotion Salary'] = df['Salary'] * 2
df
# Out:
#   Employee  Experiance    Salary               Role  Promotion Salary
# 0      Raj        10.0  125500.0        ML Engineer          251000.0
# 1    Alone         5.0   50500.0  Software Engineer          101000.0
# 2      Bob         NaN   60500.0  Software Engineer          121000.0
# 3    Kamal         1.0   30500.0        ML Engineer           61000.0
# 4   Geetha         2.0       NaN                 HR               NaN
# 5    Steve         7.0   65500.0                 HR          131000.0
# 6   Lalith         5.0   25500.0     Data Scientist           51000.0

# %% [markdown]
# # Data Cleaning

# %%
Null = df.isnull().sum()
Null.name = 'Sum'
Null
# Out:
# Employee            0
# Experiance          1
# Salary              1
# Role                0
# Promotion Salary    1
# Name: Sum, dtype: int64

# %%
df.dropna()
# Out:
#   Employee  Experiance    Salary               Role  Promotion Salary
# 0      Raj        10.0  125500.0        ML Engineer          251000.0
# 1    Alone         5.0   50500.0  Software Engineer          101000.0
# 3    Kamal         1.0   30500.0        ML Engineer           61000.0
# 5    Steve         7.0   65500.0                 HR          131000.0
# 6   Lalith         5.0   25500.0     Data Scientist           51000.0

# %%
df.dropna(how = 'any')
# or use 'all'
# Out:
#   Employee  Experiance    Salary               Role  Promotion Salary
# 0      Raj        10.0  125500.0        ML Engineer          251000.0
# 1    Alone         5.0   50500.0  Software Engineer          101000.0
# 3    Kamal         1.0   30500.0        ML Engineer           61000.0
# 5    Steve         7.0   65500.0                 HR          131000.0
# 6   Lalith         5.0   25500.0     Data Scientist           51000.0

# %%
df
# Out:
#   Employee  Experiance    Salary               Role  Promotion Salary
# 0      Raj        10.0  125500.0        ML Engineer          251000.0
# 1    Alone         5.0   50500.0  Software Engineer          101000.0
# 2      Bob         NaN   60500.0  Software Engineer          121000.0
# 3    Kamal         1.0   30500.0        ML Engineer           61000.0
# 4   Geetha         2.0       NaN                 HR               NaN
# 5    Steve         7.0   65500.0                 HR          131000.0
# 6   Lalith         5.0   25500.0     Data Scientist           51000.0

# %%
df.fillna(0)
# Out:
#   Employee  Experiance    Salary               Role  Promotion Salary
# 0      Raj        10.0  125500.0        ML Engineer          251000.0
# 1    Alone         5.0   50500.0  Software Engineer          101000.0
# 2      Bob         0.0   60500.0  Software Engineer          121000.0
# 3    Kamal         1.0   30500.0        ML Engineer           61000.0
# 4   Geetha         2.0       0.0                 HR               0.0
# 5    Steve         7.0   65500.0                 HR          131000.0
# 6   Lalith         5.0   25500.0     Data Scientist           51000.0

# %%
df['Experiance'].fillna(df['Experiance'].mean())
# Out:
# 0    10.0
# 1     5.0
# 2     5.0
# 3     1.0
# 4     2.0
# 5     7.0
# 6     5.0
# Name: Experiance, dtype: float64

# %%
df['Salary'].fillna(df['Salary'].median())
# Out:
# 0    125500.0
# 1     50500.0
# 2     60500.0
# 3     30500.0
# 4     55500.0
# 5     65500.0
# 6     25500.0
# Name: Salary, dtype: float64

# %%
df.fillna(method = 'bfill')
# Out:
# /tmp/ipython-input-3673297803.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method = 'bfill')
#   Employee  Experiance    Salary               Role  Promotion Salary
# 0      Raj        10.0  125500.0        ML Engineer          251000.0
# 1    Alone         5.0   50500.0  Software Engineer          101000.0
# 2      Bob         1.0   60500.0  Software Engineer          121000.0
# 3    Kamal         1.0   30500.0        ML Engineer           61000.0
# 4   Geetha         2.0   65500.0                 HR          131000.0
# 5    Steve         7.0   65500.0                 HR          131000.0
# 6   Lalith         5.0   25500.0     Data Scientist           51000.0

# %%
df['Promotion Salary'] = df['Promotion Salary'].apply(lambda x: x*2 if x<100000 else x)
df['Experiance'] = df['Experiance'] + 1
df
# Out:
#   Employee  Experiance    Salary               Role  Promotion Salary
# 0      Raj        12.0  125500.0        ML Engineer          251000.0
# 1    Alone         7.0   50500.0  Software Engineer          101000.0
# 2      Bob         NaN   60500.0  Software Engineer          121000.0
# 3    Kamal         3.0   30500.0        ML Engineer          122000.0
# 4   Geetha         4.0       NaN                 HR               NaN
# 5    Steve         9.0   65500.0                 HR          131000.0
# 6   Lalith         7.0   25500.0     Data Scientist          102000.0

# %% [markdown]
# # Importing Files

# %%
path = '/content/drive/MyDrive/Data_Set/healthcare_dataset.csv'
data = pd.read_csv(path)
data
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 0            2024-01-31     Matthew Smith               Sons and Miller
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55500 entries, 0 to 55499
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                55500 non-null  object
#  1   Age                 55500 non-null  int64
#  2   Gender              55500 non-null  object
#  3   Blood Type          55500 non-null  object
#  4   Medical Condition   55500 non-null  object
#  5   Date of Admission   55500 non-null  object
#  6   Doctor              55500 non-null  object
#  7   Hospital            55500 non-null  object
#  8   Insurance Provider  55500 non-null  object
#  9   Billing Amount      55500 non-null  float64
#  10  Room Number         55500 non-null  int64
#  11  Admission Type      55500 non-null  object
#  12  Discharge Date      55500 non-null  object
#  13  Medication          55500 non-null  object
#  14  Test Results        55500 non-null  object
# ...

# %%
data[['Date of Admission','Discharge Date']] = data[['Date of Admission','Discharge Date']].apply(pd.to_datetime)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55500 entries, 0 to 55499
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                55500 non-null  object
#  1   Age                 55500 non-null  int64
#  2   Gender              55500 non-null  object
#  3   Blood Type          55500 non-null  object
#  4   Medical Condition   55500 non-null  object
#  5   Date of Admission   55500 non-null  datetime64[ns]
#  6   Doctor              55500 non-null  object
#  7   Hospital            55500 non-null  object
#  8   Insurance Provider  55500 non-null  object
#  9   Billing Amount      55500 non-null  float64
#  10  Room Number         55500 non-null  int64
#  11  Admission Type      55500 non-null  object
#  12  Discharge Date      55500 non-null  datetime64[ns]
#  13  Medication          55500 non-null  object
#  14  Test Results        55500 non-null  object
# ...
